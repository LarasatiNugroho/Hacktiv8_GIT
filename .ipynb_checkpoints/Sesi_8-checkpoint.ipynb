# %% [markdown]
# ## Sesi 8

# %%
import numpy as np
import pandas as pd

# %%
df_can = pd.read_csv("data.csv")
df_can.head()
# Out:
#                                              Country Continent  \
# 0                                              India      Asia
# 1                                              China      Asia
# 2  United Kingdom of Great Britain and Northern I...    Europe
# 3                                        Philippines      Asia
# 4                                           Pakistan      Asia
#
#                Region             DevName   1980   1981   1982   1983   1984  \
# 0       Southern Asia  Developing regions   8880   8670   8147   7338   5704
# 1        Eastern Asia  Developing regions   5123   6682   3308   1863   1527
# 2     Northern Europe   Developed regions  22045  24796  20620  10015  10170
# 3  South-Eastern Asia  Developing regions   6051   5921   5249   4562   3801
# 4       Southern Asia  Developing regions    978    972   1201    900    668
#
#    1985  ...   2005   2006   2007   2008   2009   2010   2011   2012   2013  \
# ...

# %%
df_can.set_index('Country', inplace=True) #ganti index ke country

years =  list(map(str,range(1980,2014)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-eafe9e2f93c3> in <module>
# ----> 1 df_can.set_index('Country', inplace=True) #ganti index ke country
#       2
#       3 years =  list(map(str,range(1980,2014)))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['Country'] are in the columns"
